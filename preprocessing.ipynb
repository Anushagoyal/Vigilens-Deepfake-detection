# %%
#To get the average frame count 
import json
import glob
import numpy as np
import cv2
import copy
#change the path accordingly
video_files =  glob.glob('D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\*.mp4') #"C:\Users\scora\OneDrive\Desktop\Dataset\Copy of 00000.mp4"
# video_files1 =  glob.glob('D:\Deepfake_detection_using_deep_learning\ew_celeb_dataset\*.mp4')
# video_files += video_files1
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [450, 415, 512, 295, 450, 463, 486, 474, 477, 575, 422, 470, 397, 474, 461, 442, 319, 282, 435, 468, 456, 462, 471, 463, 547, 470, 499, 481, 473, 463, 472, 510, 463, 461, 505, 458, 550, 455, 467, 459, 381, 456, 383, 472, 464, 459, 471, 489, 484, 476, 470, 367, 464, 468, 417, 468, 534, 466, 507, 474, 478, 412, 478, 477, 429, 493, 457, 474, 476, 432, 357, 508, 478, 475, 471, 474, 479, 475, 492, 386, 478, 452, 462, 359, 408, 658, 482, 468, 493, 485, 416, 455, 549, 495, 414, 487, 305, 502, 453, 494, 534, 440, 457, 474, 499, 504, 327, 462, 478, 264, 479, 467, 477, 504, 340, 312, 471, 462, 474, 424, 468, 468, 362, 303, 421, 280, 455, 483, 460, 467, 398, 357, 350, 499, 481, 354, 293, 353, 481, 553, 382, 445, 450, 462, 451, 469, 722, 514, 459, 506, 461, 504, 698, 488, 375, 573, 445, 450, 455, 448, 490, 519, 447, 475, 526, 470, 469, 477, 476, 432, 348, 436, 353, 499, 465, 483, 605, 521, 468, 451, 349, 391, 478, 516, 467, 474, 510, 460, 476, 410, 465, 442, 474, 353, 462, 495, 480, 467, 
# ...

# %%
# !pip3 install tqdm

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
# !pip3 install face_recognition
#!mkdir 'D:\Deepfake_detection_using_deep_learning\FF_REAL_Face_only_data'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      #if(idx % 3 == 0):
      if(idx <= 150):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()

# %%
create_face_videos(video_files,'D:\Deepfake_detection_using_deep_learning\FF_REAL_Face_only_data')
# Out:
# No of videos already present  0
#   0%|          | 0/1469 [00:00<?, ?it/s]
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00000.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00001.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00002.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00003.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00004.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00005.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00006.mp4
# File Already exists:  D:\Deepfake_detection_using_deep_learning\sub_dataset\Dataset\Copy of 00007.mp4
# ...
